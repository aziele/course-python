# %%
message = 'Hello'      # str
price = 10             # int
pi = 3.14              # float
is_published = True    # bool
content = None         # None

print(type(message))
print(type(price))
print(type(pi))
print(type(is_published))
print(type(content))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'NoneType'>

# %% [markdown]
# Typy liczbowe

# %%
10
0
-10
# Out:
# -10

# %%
48032708423780743802748032708473280748032803408473807084378034708
# Out:
# 48032708423780743802748032708473280748032803408473807084378034708

# %%
1.23
# Out:
# 1.23

# %%
type(1.23)
# Out:
# float

# %%
4e2
# Out:
# 400.0

# %%
# 4 x 10^2

# %%
4E2
# Out:
# 400.0

# %%
4.23e-2
# Out:
# 0.0423

# %% [markdown]
# Operatory arytmetyczne

# %%
print(10 + 2)
print(10 - 2)
print(10 * 2)
print(10 / 2)
print(10 ** 2)
# Out:
# 12
# 8
# 20
# 5.0
# 100

# %%
10 + 2
# Out:
# 12

# %%
10 * 2
# Out:
# 20

# %%
10 / 2
# Out:
# 5.0

# %%
10 // 3
# Out:
# 3

# %%
10 / 3
# Out:
# 3.3333333333333335

# %%
10 % 3
# Out:
# 1

# %%
10 % 2
# Out:
# 0

# %%
11 % 2
# Out:
# 1

# %%
x = 1
print(x + 3)
# Out:
# 4

# %%
x = 3 + 4

# %%
x = x + 1

# %%
x
# Out:
# 8

# %%
x = x - 4

# %%
x
# Out:
# 4

# %%
x = x + 1

# %%
x += 1

# %%
x -= 1
x *= 2
x /= 2
x += 2

# %% [markdown]
# Kolejność wykonywania działań

# %%
x = 10 + 3 * 2

# %%
# Najwyższy priorytet mają nawiasy
x = (10 + 3) * 2
print(x)
# Out:
# 26

# %%
# 2 priorytet: potęgowanie
# 3 priorytet: mnożenie i dzielenie
# 4 priorytet: dodawanie i odejmowanie

# %% [markdown]
# Wbudowane funkcje działające na liczbach

# %%
x = abs(-10)
print(x)
# Out:
# 10

# %%
abs(10)
# Out:
# 10

# %%
round(3.75)
# Out:
# 4

# %%
round(3.75, 1)
# Out:
# 3.8

# %%
int(3.75)
# Out:
# 3

# %%
int('3')
# Out:
# 3

# %%
int('3') + 10
# Out:
# 13

# %%
float(3)
# Out:
# 3.0

# %%
float('3.7')
# Out:
# 3.7

# %%
float('3')
# Out:
# 3.0

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %%
#          9
# F = 32 + - * C
#          5

# %% [markdown]
# Konwersja temperatury

# %%
c = float(input('Enter a temperature in Celsius:'))
f = 32 + 9 / 5 * c
print(c, 'Celsius is', f, 'Fahrenheit')
# Out:
# Enter a temperature in Celsius:3
# 3.0 Celsius is 37.4 Fahrenheit

# %%
number1 = int(input('Enter 1st number: '))
number2 = int(input('Enter 2nd number: '))
print('Add:', number1 + number2)
print('Sub:', number1 - number2)
print('Mul:', number1 * number2)
print('Div:', number1 / number2)
# Out:
# Enter 1st number: 10
# Enter 2nd number: 2
# Add: 12
# Sub: 8
# Mul: 20
# Div: 5.0

# %%
seconds = int(input('Enter a number of seconds: '))
hours = seconds // 3600
seconds = seconds % 3600
minutes = seconds // 60
seconds = seconds % 60
print(hours, 'h', minutes, 'm', seconds, 's')
# Out:
# Enter a number of seconds: 6000
# 1 h 40 m 0 s
